# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
mydata=pd.read_csv('Food Prices.csv')
mydata
# Out:
#        Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 0     Australia   2018       1      Bread                Loaf            2.20
# 1     Australia   2018       2      Bread                Loaf            2.20
# 2     Australia   2018       3      Bread                Loaf            2.20
# 3     Australia   2018       4      Bread                Loaf            2.21
# 4     Australia   2018       5      Bread                Loaf            2.21
# ...         ...    ...     ...        ...                 ...             ...
# 1195     Canada   2022       8   Potatoes                1 Kg            3.17
# 1196     Canada   2022       9   Potatoes                1 Kg            3.18
# 1197     Canada   2022      10   Potatoes                1 Kg            3.20
# 1198     Canada   2022      11   Potatoes                1 Kg            3.21
# 1199     Canada   2022      12   Potatoes                1 Kg            3.22
#
# ...

# %%
mydata
# Out:
#        Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 0     Australia   2018       1      Bread                Loaf            2.20
# 1     Australia   2018       2      Bread                Loaf            2.20
# 2     Australia   2018       3      Bread                Loaf            2.20
# 3     Australia   2018       4      Bread                Loaf            2.21
# 4     Australia   2018       5      Bread                Loaf            2.21
# ...         ...    ...     ...        ...                 ...             ...
# 1195     Canada   2022       8   Potatoes                1 Kg            3.17
# 1196     Canada   2022       9   Potatoes                1 Kg            3.18
# 1197     Canada   2022      10   Potatoes                1 Kg            3.20
# 1198     Canada   2022      11   Potatoes                1 Kg            3.21
# 1199     Canada   2022      12   Potatoes                1 Kg            3.22
#
# ...

# %%
dat=mydata[mydata['Year ']==2022]
dat
# Out:
#        Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 48    Australia   2022       1      Bread                Loaf            2.70
# 49    Australia   2022       2      Bread                Loaf            2.72
# 50    Australia   2022       3      Bread                Loaf            2.74
# 51    Australia   2022       4      Bread                Loaf            2.76
# 52    Australia   2022       5      Bread                Loaf            2.78
# ...         ...    ...     ...        ...                 ...             ...
# 1195     Canada   2022       8   Potatoes                1 Kg            3.17
# 1196     Canada   2022       9   Potatoes                1 Kg            3.18
# 1197     Canada   2022      10   Potatoes                1 Kg            3.20
# 1198     Canada   2022      11   Potatoes                1 Kg            3.21
# 1199     Canada   2022      12   Potatoes                1 Kg            3.22
#
# ...

# %%
dat[dat['Country ']=='Sweden']
# Out:
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 288   Sweden   2022       1      Bread                Loaf           23.17
# 289   Sweden   2022       2      Bread                Loaf           23.41
# 290   Sweden   2022       3      Bread                Loaf           23.65
# 291   Sweden   2022       4      Bread                Loaf           23.89
# 292   Sweden   2022       5      Bread                Loaf           24.13
# 293   Sweden   2022       6      Bread                Loaf           24.37
# 294   Sweden   2022       7      Bread                Loaf           24.61
# 295   Sweden   2022       8      Bread                Loaf           24.85
# 296   Sweden   2022       9      Bread                Loaf           25.09
# 297   Sweden   2022      10      Bread                Loaf           25.33
# 298   Sweden   2022      11      Bread                Loaf           25.57
# ...

# %%
dat[dat['Country ']=='Sweden'].count()
# Out:
# Country                48
# Year                   48
# Month                  48
# Food Item              48
# Unit of Measurement    48
# Average Price          48
# Currency               48
# Price in USD           48
# Availability           48
# Quality                48
# dtype: int64

# %%
swe_dat=dat[dat['Country ']=='Sweden']#Food price analysis of sweden in fiscal year 2022
swe_dat
# Out:
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 288   Sweden   2022       1      Bread                Loaf           23.17
# 289   Sweden   2022       2      Bread                Loaf           23.41
# 290   Sweden   2022       3      Bread                Loaf           23.65
# 291   Sweden   2022       4      Bread                Loaf           23.89
# 292   Sweden   2022       5      Bread                Loaf           24.13
# 293   Sweden   2022       6      Bread                Loaf           24.37
# 294   Sweden   2022       7      Bread                Loaf           24.61
# 295   Sweden   2022       8      Bread                Loaf           24.85
# 296   Sweden   2022       9      Bread                Loaf           25.09
# 297   Sweden   2022      10      Bread                Loaf           25.33
# 298   Sweden   2022      11      Bread                Loaf           25.57
# ...

# %%
print("Price of bread 🥪 in Sweden in succesive months of year 2022......")
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="Month ",y="Average Price ",data=swe_dat[swe_dat['Food Item ']=='Bread'],hue='Month ')
plt.show()
# Out:
# Price of bread 🥪 in Sweden in succesive months of year 2022......

# %%
print("Price analysis of Milk 🥛  in the year 2022 in Sweden")
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="Month ",y="Average Price ",data=swe_dat[swe_dat['Food Item ']=='Milk'])
plt.show()
# Out:
# Price analysis of Milk 🥛  in the year 2022 in Sweden

# %%
print("Price analysis of Potato in the year 2022 in Sweden.")
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="Month ",y="Average Price ",data=swe_dat[swe_dat['Food Item ']=='Potatoes'],hue='Month ')
plt.show()
# Out:
# Price analysis of Potato in the year 2022 in Sweden.

# %%
mydata['Food Item '].drop_duplicates().count()
# Out:
# 4

# %%
mydata['Food Item '].drop_duplicates()
# Out:
# 0         Bread
# 60         Milk
# 120        Eggs
# 180    Potatoes
# Name: Food Item , dtype: object

# %%
aus_dat=mydata[mydata['Country ']=='Australia']
aus_dat
# Out:
#       Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 0    Australia   2018       1      Bread                Loaf            2.20
# 1    Australia   2018       2      Bread                Loaf            2.20
# 2    Australia   2018       3      Bread                Loaf            2.20
# 3    Australia   2018       4      Bread                Loaf            2.21
# 4    Australia   2018       5      Bread                Loaf            2.21
# ..         ...    ...     ...        ...                 ...             ...
# 235  Australia   2022       8   Potatoes                1 Kg            3.99
# 236  Australia   2022       9   Potatoes                1 Kg            4.03
# 237  Australia   2022      10   Potatoes                1 Kg            4.06
# 238  Australia   2022      11   Potatoes                1 Kg            4.10
# 239  Australia   2022      12   Potatoes                1 Kg            4.13
#
# ...

# %%
aus_dat[aus_dat['Year ']==2018]
# Out:
#       Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 0    Australia   2018       1      Bread                Loaf            2.20
# 1    Australia   2018       2      Bread                Loaf            2.20
# 2    Australia   2018       3      Bread                Loaf            2.20
# 3    Australia   2018       4      Bread                Loaf            2.21
# 4    Australia   2018       5      Bread                Loaf            2.21
# 5    Australia   2018       6      Bread                Loaf            2.22
# 6    Australia   2018       7      Bread                Loaf            2.22
# 7    Australia   2018       8      Bread                Loaf            2.22
# 8    Australia   2018       9      Bread                Loaf            2.23
# 9    Australia   2018      10      Bread                Loaf            2.23
# 10   Australia   2018      11      Bread                Loaf            2.24
# ...

# %%
aus_dat[aus_dat['Year ']==2018].count()
# Out:
# Country                48
# Year                   48
# Month                  48
# Food Item              48
# Unit of Measurement    48
# Average Price          48
# Currency               48
# Price in USD           48
# Availability           48
# Quality                48
# dtype: int64

# %%
print("Price analysis of eggs in australia in the fiscal year 2018")
sns.set(rc={'figure.figsize':(15,8)})
sns.barplot(x="Month ",y="Average Price ",data=aus_dat[aus_dat['Food Item ']=='Eggs'],hue='Month ')
plt.show()
# Out:
# Price analysis of eggs in australia in the fiscal year 2018

# %%
print("Price analysis of eggs in australia in the fiscal year 2018")
sns.set(rc={'figure.figsize':(15,9)})
sns.lineplot(x="Month ",y="Average Price ",data=aus_dat[aus_dat['Food Item ']=='Eggs'],color='Blue')
plt.show()
# Out:
# Price analysis of eggs in australia in the fiscal year 2018

# %%
aus_dat
# Out:
#       Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 0    Australia   2018       1      Bread                Loaf            2.20
# 1    Australia   2018       2      Bread                Loaf            2.20
# 2    Australia   2018       3      Bread                Loaf            2.20
# 3    Australia   2018       4      Bread                Loaf            2.21
# 4    Australia   2018       5      Bread                Loaf            2.21
# ..         ...    ...     ...        ...                 ...             ...
# 235  Australia   2022       8   Potatoes                1 Kg            3.99
# 236  Australia   2022       9   Potatoes                1 Kg            4.03
# 237  Australia   2022      10   Potatoes                1 Kg            4.06
# 238  Australia   2022      11   Potatoes                1 Kg            4.10
# 239  Australia   2022      12   Potatoes                1 Kg            4.13
#
# ...

# %%
print("Price analysis of Milk in Australia in the fiscal year 2018.....")
sns.set(rc={'figure.figsize':(15,9)})
sns.barplot(x="Month ",y="Average Price ",data=aus_dat[aus_dat['Food Item ']=='Milk'],hue='Month ')
# Out:
# Price analysis of Milk in Australia in the fiscal year 2018.....
# <AxesSubplot:xlabel='Month ', ylabel='Average Price '>

# %%
print("Price analysis of Bread in Australia in the fiscal year 2018.....")
sns.set(rc={'figure.figsize':(15,9)})
sns.lineplot(x="Month ",y="Average Price ",data=aus_dat[aus_dat['Food Item ']=='Bread'],color='Green')
plt.show()
# Out:
# Price analysis of Bread in Australia in the fiscal year 2018.....

# %%
mydata['Country '].drop_duplicates().count()
# Out:
# 5

# %%
mydata['Country '].drop_duplicates()
# Out:
# 0         Australia
# 240          Sweden
# 480           Japan
# 720    South Africa
# 960          Canada
# Name: Country , dtype: object

# %%
jap_dat=mydata[mydata['Country ']=='Japan']
jap_dat
# Out:
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 480    Japan   2018       1      Bread                Loaf          186.39
# 481    Japan   2018       2      Bread                Loaf          186.87
# 482    Japan   2018       3      Bread                Loaf          187.35
# 483    Japan   2018       4      Bread                Loaf          187.83
# 484    Japan   2018       5      Bread                Loaf          188.31
# ..       ...    ...     ...        ...                 ...             ...
# 715    Japan   2022       8   Potatoes                1 Kg          414.39
# 716    Japan   2022       9   Potatoes                1 Kg          416.15
# 717    Japan   2022      10   Potatoes                1 Kg          417.91
# 718    Japan   2022      11   Potatoes                1 Kg          419.67
# 719    Japan   2022      12   Potatoes                1 Kg          421.43
#
#     Currency   Price in USD  Availability  Quality
# ...

# %%
jap_dat19=jap_dat[jap_dat['Year ']==2019]
jap_dat19
# Out:
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 492    Japan   2019       1      Bread                Loaf          192.15
# 493    Japan   2019       2      Bread                Loaf          192.48
# 494    Japan   2019       3      Bread                Loaf          192.81
# 495    Japan   2019       4      Bread                Loaf          193.14
# 496    Japan   2019       5      Bread                Loaf          193.47
# 497    Japan   2019       6      Bread                Loaf          193.80
# 498    Japan   2019       7      Bread                Loaf          194.13
# 499    Japan   2019       8      Bread                Loaf          194.46
# 500    Japan   2019       9      Bread                Loaf          194.79
# 501    Japan   2019      10      Bread                Loaf          195.12
# 502    Japan   2019      11      Bread                Loaf          195.45
# ...

# %%
print("Price analysis of Bread in Japan in the fiscal year 2019")
sns.set(rc={'figure.figsize':(15,9)})
sns.barplot(x="Month ",y="Average Price ",data=jap_dat19[jap_dat19['Food Item ']=='Bread'],hue='Month ')
plt.show()
# Out:
# Price analysis of Bread in Japan in the fiscal year 2019

# %%
print("Price analysis of Milk in Japan in the fiscal year 2019")
sns.set(rc={'figure.figsize':(15,9)})
sns.lineplot(x="Month ",y="Average Price ",data=jap_dat19[jap_dat19['Food Item ']=='Milk'],color='Red')
plt.show()
# Out:
# Price analysis of Milk in Japan in the fiscal year 2019

# %%
jap_dat21=jap_dat[jap_dat['Year ']==2021]
jap_dat21
# Out:
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 516    Japan   2021       1      Bread                Loaf          191.52
# 517    Japan   2021       2      Bread                Loaf          192.01
# 518    Japan   2021       3      Bread                Loaf          192.50
# 519    Japan   2021       4      Bread                Loaf          192.99
# 520    Japan   2021       5      Bread                Loaf          193.48
# 521    Japan   2021       6      Bread                Loaf          193.97
# 522    Japan   2021       7      Bread                Loaf          194.46
# 523    Japan   2021       8      Bread                Loaf          194.95
# 524    Japan   2021       9      Bread                Loaf          195.44
# 525    Japan   2021      10      Bread                Loaf          195.93
# 526    Japan   2021      11      Bread                Loaf          196.42
# ...

# %%
print("Price analysis of Potatoes in Japan in fiscal year 2021")
sns.set(rc={'figure.figsize':(15,8)})
sns.relplot(x="Month ",y="Average Price ",data=jap_dat21[jap_dat21['Food Item ']=='Potatoes'])
plt.show()
# Out:
# Price analysis of Potatoes in Japan in fiscal year 2021

# %%
mydata['Country '].drop_duplicates()
# Out:
# 0         Australia
# 240          Sweden
# 480           Japan
# 720    South Africa
# 960          Canada
# Name: Country , dtype: object

# %%
can_dat=mydata[mydata['Country ']=='Canada']
can_dat
# Out:
#      Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 960    Canada   2018       1      Bread                Loaf            2.87
# 961    Canada   2018       2      Bread                Loaf            2.88
# 962    Canada   2018       3      Bread                Loaf            2.88
# 963    Canada   2018       4      Bread                Loaf            2.89
# 964    Canada   2018       5      Bread                Loaf            2.89
# ...       ...    ...     ...        ...                 ...             ...
# 1195   Canada   2022       8   Potatoes                1 Kg            3.17
# 1196   Canada   2022       9   Potatoes                1 Kg            3.18
# 1197   Canada   2022      10   Potatoes                1 Kg            3.20
# 1198   Canada   2022      11   Potatoes                1 Kg            3.21
# 1199   Canada   2022      12   Potatoes                1 Kg            3.22
#
#      Currency   Price in USD  Availability  Quality
# ...

# %%
can_dat20=can_dat[can_dat['Year ']==2020]
can_dat20
# Out:
#      Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 984    Canada   2020       1      Bread                Loaf            3.03
# 985    Canada   2020       2      Bread                Loaf            3.03
# 986    Canada   2020       3      Bread                Loaf            3.03
# 987    Canada   2020       4      Bread                Loaf            3.03
# 988    Canada   2020       5      Bread                Loaf            3.03
# 989    Canada   2020       6      Bread                Loaf            3.04
# 990    Canada   2020       7      Bread                Loaf            3.04
# 991    Canada   2020       8      Bread                Loaf            3.04
# 992    Canada   2020       9      Bread                Loaf            3.04
# 993    Canada   2020      10      Bread                Loaf            3.04
# 994    Canada   2020      11      Bread                Loaf            3.04
# ...

# %%
print("Price analysis of Eggs in Canada in the fiscal year 2020........")
sns.set(rc={'figure.figsize':(13,9)})
sns.barplot(x="Month ",y="Average Price ",data=can_dat20[can_dat20['Food Item ']=='Eggs'],hue='Month ')
plt.show()
# Out:
# Price analysis of Eggs in Canada in the fiscal year 2020........
